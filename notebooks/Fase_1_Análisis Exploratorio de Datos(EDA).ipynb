# %%
import pandas as pd

# %%
import openpyxl

# %%
## Creamos un dataframe para cargar y visualizar los de datos que tenemos en excel,  en formato de tabla.
## Especificamos index_col=0, para que la columna 0 del archivo se use como índice de fila. De lo contrario, pandas crearia otra columna de indice más llamada Unnamed.

df = pd.read_csv("../data/hr_raw_data_final.csv", index_col=0)

# %%
pd.set_option('display.max_columns', None)

# %%
## Echamos un vistazo a las 50 primeras filas de nuestro df.

df.head()
# Out:
#   age attrition businesstravel    dailyrate                department  \
# 0  51        No            NaN  2015.722222                       NaN
# 1  52        No            NaN  2063.388889                       NaN
# 2  42        No  travel_rarely  1984.253968   Research & Development
# 3  47        No  travel_rarely  1771.404762                       NaN
# 4  46        No            NaN  1582.771346                       NaN
#
#    distancefromhome  education    educationfield  employeecount  \
# 0                 6          3               NaN              1
# 1                 1          4     Life Sciences              1
# 2                 4          2  Technical Degree              1
# 3                 2          4           Medical              1
# 4                 3          3  Technical Degree              1
#
#    employeenumber  environmentsatisfaction  gender  hourlyrate  \
# 0               1                        1       0         NaN
# ...

# %%
## Para conocer la estructura de nuestra tabla (filas x columnas)

df.shape
# Out:
# (1678, 41)

# %%
## Para extraer el nombre de nuestras columnas.

df.columns
# Out:
# Index(['age', 'attrition', 'businesstravel', 'dailyrate', 'department',
#        'distancefromhome', 'education', 'educationfield', 'employeecount',
#        'employeenumber', 'environmentsatisfaction', 'gender', 'hourlyrate',
#        'jobinvolvement', 'joblevel', 'jobrole', 'jobsatisfaction',
#        'maritalstatus', 'monthlyincome', 'monthlyrate', 'numcompaniesworked',
#        'over18', 'overtime', 'percentsalaryhike', 'performancerating',
#        'relationshipsatisfaction', 'standardhours', 'stockoptionlevel',
#        'totalworkingyears', 'trainingtimeslastyear', 'worklifebalance',
#        'yearsatcompany', 'yearsincurrentrole', 'yearssincelastpromotion',
#        'yearswithcurrmanager', 'sameasmonthlyincome', 'datebirth', 'salary',
#        'roledepartament', 'numberchildren', 'remotework'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1678 entries, 0 to 1677
# Data columns (total 41 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   age                       1678 non-null   object
#  1   attrition                 1678 non-null   object
#  2   businesstravel            877 non-null    object
#  3   dailyrate                 1678 non-null   float64
#  4   department                312 non-null    object
#  5   distancefromhome          1678 non-null   int64
#  6   education                 1678 non-null   int64
#  7   educationfield            904 non-null    object
#  8   employeecount             1678 non-null   int64
#  9   employeenumber            1678 non-null   int64
#  10  environmentsatisfaction   1678 non-null   int64
#  11  gender                    1678 non-null   int64
#  12  hourlyrate                411 non-null    float64
#  13  jobinvolvement            1678 non-null   int64
# ...

# %%
# observamos que hay cifras negativas en la "distancefromhome", debemos buscar si hay más cifras negativas
# observamos que la columna ""numberchildren" no nos aporta ninguna información
df.describe().T
# Out:
#                            count         mean         std          min  \
# dailyrate                 1678.0   668.079714  470.787298   104.103175
# distancefromhome          1678.0     4.504172   14.652066   -49.000000
# education                 1678.0     2.932658    1.024270     1.000000
# employeecount             1678.0     1.000000    0.000000     1.000000
# employeenumber            1678.0   809.859952  467.084867     1.000000
# environmentsatisfaction   1678.0     4.264005    6.912695     1.000000
# gender                    1678.0     0.398689    0.489774     0.000000
# hourlyrate                 411.0    83.140768   57.272101    13.012897
# jobinvolvement            1678.0     2.740763    0.710359     1.000000
# joblevel                  1678.0     2.064362    1.099425     1.000000
# jobsatisfaction           1678.0     2.743147    1.105172     1.000000
# numcompaniesworked        1678.0     2.670441    2.501133     0.000000
# ...

# %%
# encontramos valores numericos que aparecen con str porq tienen "comas" en vez de puntos
# hay varias columnas que tienen palabras con mayúsculas y minúsculas 

df.describe(include="object").T
# Out:
#                     count unique  \
# age                  1678     54
# attrition            1678      2
# businesstravel        877      3
# department            312      3
# educationfield        904      6
# jobrole              1678   1579
# maritalstatus        1003      5
# monthlyincome        1189    493
# monthlyrate          1678    673
# over18                740      1
# overtime              982      2
# performancerating    1478      2
# standardhours        1327      2
# totalworkingyears    1129     40
# worklifebalance      1564      4
# yearsincurrentrole     35     10
# sameasmonthlyincome  1189    493
# salary               1393    583
# roledepartament       312    301
# remotework           1678      5
#
#                                                                  top  freq
# age                                                               35    88
# attrition                                                         No  1406
# ...

# %%
df.select_dtypes(include=["int", "float"])
# Out:
#         dailyrate  distancefromhome  education  employeecount  employeenumber  \
# 0     2015.722222                 6          3              1               1
# 1     2063.388889                 1          4              1               2
# 2     1984.253968                 4          2              1               3
# 3     1771.404762                 2          4              1               4
# 4     1582.771346                 3          3              1               5
# ...           ...               ...        ...            ...             ...
# 1673   488.944444               -26          3              1             824
# 1674  1973.984127                26          4              1            1087
# 1675   290.035510                15          3              1             528
# 1676  1032.487286                 4          3              1              76
# 1677   556.256661                 2          2              1             401
#
# ...

# %%
df.select_dtypes(include='object')
# Out:
#      age attrition businesstravel                department    educationfield  \
# 0     51        No            NaN                       NaN               NaN
# 1     52        No            NaN                       NaN     Life Sciences
# 2     42        No  travel_rarely   Research & Development   Technical Degree
# 3     47        No  travel_rarely                       NaN           Medical
# 4     46        No            NaN                       NaN  Technical Degree
# ...   ..       ...            ...                       ...               ...
# 1673  43        No            NaN                       NaN           Medical
# 1674  47        No            NaN                       NaN               NaN
# 1675  29        No  travel_rarely                       NaN               NaN
# 1676  47        No  travel_rarely                       NaN     Life Sciences
# 1677  32        No            NaN                       NaN     Life Sciences
#
# ...

# %%
# creamos una variable con los nombres de las columnas del DataFrame de las variables categóricas utilizando el método '.columns'
columnas_df = df.columns
print(f"Las columnas del DataFrame de variables categóricas son {columnas_df}")

# empezamos a iterar por cada una de las columnas para sacar sus valores únicos y sus frecuencias
for columna in columnas_df:
    print(f" \n----------- ESTAMOS ANALIZANDO LA COLUMNA: '{columna.upper()}' -----------\n")
    print(f"Sus valores únicos son: {df[columna].unique()}\n")
    print(f"Las frecuencias de los valores únicos de las categorías son: {df[columna].value_counts()} ")
# Out:
# Las columnas del DataFrame de variables categóricas son Index(['age', 'attrition', 'businesstravel', 'dailyrate', 'department',
#        'distancefromhome', 'education', 'educationfield', 'employeecount',
#        'employeenumber', 'environmentsatisfaction', 'gender', 'hourlyrate',
#        'jobinvolvement', 'joblevel', 'jobrole', 'jobsatisfaction',
#        'maritalstatus', 'monthlyincome', 'monthlyrate', 'numcompaniesworked',
#        'over18', 'overtime', 'percentsalaryhike', 'performancerating',
#        'relationshipsatisfaction', 'standardhours', 'stockoptionlevel',
#        'totalworkingyears', 'trainingtimeslastyear', 'worklifebalance',
#        'yearsatcompany', 'yearsincurrentrole', 'yearssincelastpromotion',
#        'yearswithcurrmanager', 'sameasmonthlyincome', 'datebirth', 'salary',
#        'roledepartament', 'numberchildren', 'remotework'],
#       dtype='object')
#
# ----------- ESTAMOS ANALIZANDO LA COLUMNA: 'AGE' -----------
#
# ...

# %%
df.isnull().sum()
# Out:
# age                            0
# attrition                      0
# businesstravel               801
# dailyrate                      0
# department                  1366
# distancefromhome               0
# education                      0
# educationfield               774
# employeecount                  0
# employeenumber                 0
# environmentsatisfaction        0
# gender                         0
# hourlyrate                  1267
# jobinvolvement                 0
# joblevel                       0
# jobrole                        0
# jobsatisfaction                0
# maritalstatus                675
# monthlyincome                489
# monthlyrate                    0
# numcompaniesworked             0
# over18                       938
# overtime                     696
# percentsalaryhike              0
# performancerating            200
# relationshipsatisfaction       0
# standardhours                351
# stockoptionlevel               0
# ...

# %%
df.notnull().sum()
# Out:
# age                         1678
# attrition                   1678
# businesstravel               877
# dailyrate                   1678
# department                   312
# distancefromhome            1678
# education                   1678
# educationfield               904
# employeecount               1678
# employeenumber              1678
# environmentsatisfaction     1678
# gender                      1678
# hourlyrate                   411
# jobinvolvement              1678
# joblevel                    1678
# jobrole                     1678
# jobsatisfaction             1678
# maritalstatus               1003
# monthlyincome               1189
# monthlyrate                 1678
# numcompaniesworked          1678
# over18                       740
# overtime                     982
# percentsalaryhike           1678
# performancerating           1478
# relationshipsatisfaction    1678
# standardhours               1327
# stockoptionlevel            1678
# ...

# %%
porc_nulos = (df.isnull().sum() / df.shape[0]) * 100
porc_nulos
# Out:
# age                           0.000000
# attrition                     0.000000
# businesstravel               47.735399
# dailyrate                     0.000000
# department                   81.406436
# distancefromhome              0.000000
# education                     0.000000
# educationfield               46.126341
# employeecount                 0.000000
# employeenumber                0.000000
# environmentsatisfaction       0.000000
# gender                        0.000000
# hourlyrate                   75.506555
# jobinvolvement                0.000000
# joblevel                      0.000000
# jobrole                       0.000000
# jobsatisfaction               0.000000
# maritalstatus                40.226460
# monthlyincome                29.141836
# monthlyrate                   0.000000
# numcompaniesworked            0.000000
# over18                       55.899881
# overtime                     41.477950
# percentsalaryhike             0.000000
# ...

# %%
# lo convertimos a DataFrame
df_nulos = pd.DataFrame(porc_nulos, columns = ["%_nulos"])

# filtramos el DataFrame para quedarnos solo con aquellas columnas que tengan nulos
df_nulos[df_nulos["%_nulos"] > 0].sort_values(by="%_nulos", ascending=False)
# Out:
#                         %_nulos
# numberchildren       100.000000
# yearsincurrentrole    97.914184
# roledepartament       81.406436
# department            81.406436
# hourlyrate            75.506555
# over18                55.899881
# businesstravel        47.735399
# educationfield        46.126341
# overtime              41.477950
# maritalstatus         40.226460
# totalworkingyears     32.717521
# monthlyincome         29.141836
# sameasmonthlyincome   29.141836
# standardhours         20.917759
# salary                16.984505
# performancerating     11.918951
# worklifebalance        6.793802

# %%
nulos_cat = df[df.columns[df.isnull().any()]].select_dtypes(include = "O").columns
print(f'las columnas categóricas que tienen nulos son:\n {nulos_cat}\n')
# Out:
# las columnas categóricas que tienen nulos son:
#  Index(['businesstravel', 'department', 'educationfield', 'maritalstatus',
#        'monthlyincome', 'over18', 'overtime', 'performancerating',
#        'standardhours', 'totalworkingyears', 'worklifebalance',
#        'yearsincurrentrole', 'sameasmonthlyincome', 'salary',
#        'roledepartament'],
#       dtype='object')

# %%
for col in nulos_cat:
    print(f'la distribución de las categorías por columna {col.upper()} es:')
    display(df[col].value_counts() / df.shape[0])
    print('----------')
# Out:
# la distribución de las categorías por columna BUSINESSTRAVEL es:
# businesstravel
# travel_rarely        0.367104
# travel_frequently    0.100119
# non-travel           0.055423
# Name: count, dtype: float64
# ----------
# la distribución de las categorías por columna DEPARTMENT es:
# department
# Research & Development     0.120977
# Sales                      0.055423
# Human Resources            0.009535
# Name: count, dtype: float64
# ----------
# la distribución de las categorías por columna EDUCATIONFIELD es:
# educationfield
# Life Sciences       0.218713
# Medical             0.170441
# Marketing           0.063170
# Technical Degree    0.041716
# Other               0.037545
# Human Resources     0.007151
# Name: count, dtype: float64
# ----------
# la distribución de las categorías por columna MARITALSTATUS es:
# maritalstatus
# Married     0.249702
# Single      0.204410
# Divorced    0.115614
# Marreid     0.021454
# divorced    0.006555
# Name: count, dtype: float64
# ...

# %%
df.duplicated().sum()
# Out:
# 64

# %%
df.duplicated(keep=False).sum()
# Out:
# 128

# %%
duplicated_rows = df[df.duplicated()]
print("Filas duplicadas en todo el DataFrame:")
print(duplicated_rows)
# Out:
# Filas duplicadas en todo el DataFrame:
#      age attrition businesstravel    dailyrate         department  \
# 1614  35        No            NaN  1032.487286                NaN
# 1615  59        No  travel_rarely   290.035510   Human Resources
# 1616  30        No  travel_rarely  1032.487286                NaN
# 1617  34       Yes  travel_rarely   556.256661                NaN
# 1618  47        No            NaN   290.035510                NaN
# ...   ..       ...            ...          ...                ...
# 1673  43        No            NaN   488.944444                NaN
# 1674  47        No            NaN  1973.984127                NaN
# 1675  29        No  travel_rarely   290.035510                NaN
# 1676  47        No  travel_rarely  1032.487286                NaN
# 1677  32        No            NaN   556.256661                NaN
#
#       distancefromhome  education educationfield  employeecount  \
# 1614                18          5  Life Sciences              1
# ...

# %%
pd.set_option('display.max_rows', None)

# %%
duplicated_rows.head()
# Out:
#      age attrition businesstravel    dailyrate         department  \
# 1614  35        No            NaN  1032.487286                NaN
# 1615  59        No  travel_rarely   290.035510   Human Resources
# 1616  30        No  travel_rarely  1032.487286                NaN
# 1617  34       Yes  travel_rarely   556.256661                NaN
# 1618  47        No            NaN   290.035510                NaN
#
#       distancefromhome  education educationfield  employeecount  \
# 1614                18          5  Life Sciences              1
# 1615                 6          2        Medical              1
# 1616                 5          3            NaN              1
# 1617                24          4            NaN              1
# 1618                 2          4  Life Sciences              1
#
#       employeenumber  environmentsatisfaction  gender  hourlyrate  \
# 1614             178                        2       0         NaN
# ...

# %%
df[df.duplicated(keep=False)].sort_values("employeenumber")
# Out:
#      age attrition businesstravel    dailyrate department  distancefromhome  \
# 8     41        No            NaN  1712.182540        NaN                 2
# 1656  41        No            NaN  1712.182540        NaN                 2
# 60    36        No            NaN   610.174603        NaN                 5
# 1652  36        No            NaN   610.174603        NaN                 5
# 1676  47        No  travel_rarely  1032.487286        NaN                 4
# ...   ..       ...            ...          ...        ...               ...
# 1638  48        No  travel_rarely   417.960317        NaN                 2
# 1657  45        No  travel_rarely   495.753968        NaN                 2
# 1568  45        No  travel_rarely   495.753968        NaN                 2
# 1671  31        No            NaN   556.256661        NaN                12
# 1607  31        No            NaN   556.256661        NaN                12
#
# ...
