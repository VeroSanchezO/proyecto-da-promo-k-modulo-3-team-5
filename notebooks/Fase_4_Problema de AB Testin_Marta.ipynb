# %%
import pandas as pd
import numpy as np
import scipy.stats as stats
from scipy.stats import shapiro, poisson, chisquare, expon, kstest
from scipy.stats import shapiro, levene
from scipy.stats import ttest_ind
from scipy.stats import mannwhitneyu
from scipy.stats import chi2_contingency
import seaborn as sn
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Gestión de los warnings
# -----------------------------------------------------------------------
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# **Hipótesis:**
# Existe una relación entre el nivel de satisfacción en el trabajo y la rotación de empleados en la empresa. Se sospecha que los empleados con niveles de satisfacción más bajos tienen una mayor probabilidad de dejar la empresa

# %%
df_testing = pd.read_csv('df_final.csv', index_col=0)
pd.set_option('display.max_columns', None)

df_testing.head()
# Out:
#    age attrition business_travel   daily_rate  distance_from_home  education  \
# 0   51        No         Unknown  2015.722222                   6          3
# 1   52        No         Unknown  2063.388889                   1          4
# 2   42        No   travel_rarely  1984.253968                   4          2
# 3   47        No   travel_rarely  1771.404762                   2          4
# 4   46        No         Unknown  1582.771346                   3          3
#
#     education_field  employee_number  environment_satisfaction gender  \
# 0           Unknown                1                         1      M
# 1     life sciences                2                         3      M
# 2  technical degree                3                         3      M
# 3           medical                4                         1      F
# 4  technical degree                5                         1      F
#
#    job_involvement  job_level             job_role  job_satisfaction  \
# 0                3          5   research director                  3
# 1                2          5             manager                  3
# 2                3          5             manager                  4
# 3                3          4   research director                  3
# 4                4          4     sales executive                  1
#
#   marital_status  monthly_income  monthly_rate  num_companies_worked overtime  \
# 0        Unknown        16280.83      42330.17                     7       no
# 1        Unknown        16665.83      43331.17                     0  Unknown
# 2        married        16026.67      41669.33                     1       no
# 3        married        14307.50      37199.50                     3  Unknown
# 4       divorced        12783.92      33238.20                     2       no
#
#    percent_salary_hike  performance_rating  relationship_satisfaction  \
# 0                   13                 3.0                          3
# 1                   14                 3.0                          1
# 2                   11                 3.0                          4
# 3                   19                 3.0                          2
# 4                   12                 3.0                          4
#
#   standard_hours  stock_option_level total_working_years  \
# 0      Full Time                   0             Unknown
# 1        Unknown                   1                34.0
# 2        Unknown                   0                22.0
# 3      Full Time                   2             Unknown
# 4        Unknown                   1             Unknown
#
#    training_times_last_year work_life_balance  years_at_company  \
# 0                         5               3.0                20
# 1                         5               3.0                33
# 2                         3           Unknown                22
# 3                         2           Unknown                20
# 4                         5               3.0                19
#
#    years_since_last_promotion  years_with_curr_manager     salary remote_work
# 0                          15                       15  195370.00           Y
# 1                          11                        9  199990.00           Y
# 2                          11                       15  192320.00           Y
# 3                           5                        6  171690.00           N
# 4                           2                        8  153407.04           N

# %%
df_testing["job_satisfaction"].unique()
# Out:
# array([3, 4, 1, 2])

# %%
df_testing["relationship_satisfaction"].unique()
# Out:
# array([3, 1, 4, 2])

# %%
df_testing["environment_satisfaction"].unique()
# Out:
# array([ 1,  3,  4,  2, 42, 37, 35, 25, 27, 31, 39, 21, 15, 14, 33, 19, 12,
#        13, 28, 47, 36, 29, 24, 46, 16, 22, 41, 49, 11, 48, 18, 10, 45, 38,
#        17, 20, 26, 43])

# %%
df_testing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1614 entries, 0 to 1613
# Data columns (total 32 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   age                         1614 non-null   int64
#  1   attrition                   1614 non-null   object
#  2   business_travel             1614 non-null   object
#  3   daily_rate                  1614 non-null   float64
#  4   distance_from_home          1614 non-null   int64
#  5   education                   1614 non-null   int64
#  6   education_field             1614 non-null   object
#  7   employee_number             1614 non-null   int64
#  8   environment_satisfaction    1614 non-null   int64
#  9   gender                      1614 non-null   object
#  10  job_involvement             1614 non-null   int64
#  11  job_level                   1614 non-null   int64
#  12  job_role                    1614 non-null   object
#  13  job_satisfaction            1614 non-null   int64
#  14  marital_status              1614 non-null   object
#  15  monthly_income              1614 non-null   float64
#  16  monthly_rate                1614 non-null   float64
#  17  num_companies_worked        1614 non-null   int64
#  18  overtime                    1614 non-null   object
#  19  percent_salary_hike         1614 non-null   int64
#  20  performance_rating          1614 non-null   float64
#  21  relationship_satisfaction   1614 non-null   int64
#  22  standard_hours              1614 non-null   object
#  23  stock_option_level          1614 non-null   int64
#  24  total_working_years         1614 non-null   object
#  25  training_times_last_year    1614 non-null   int64
#  26  work_life_balance           1614 non-null   object
#  27  years_at_company            1614 non-null   int64
#  28  years_since_last_promotion  1614 non-null   int64
#  29  years_with_curr_manager     1614 non-null   int64
#  30  salary                      1614 non-null   float64
#  31  remote_work                 1614 non-null   object
# dtypes: float64(5), int64(16), object(11)
# memory usage: 416.1+ KB

# %%
df_testing.columns
# Out:
# Index(['age', 'attrition', 'business_travel', 'daily_rate',
#        'distance_from_home', 'education', 'education_field', 'employee_number',
#        'environment_satisfaction', 'gender', 'job_involvement', 'job_level',
#        'job_role', 'job_satisfaction', 'marital_status', 'monthly_income',
#        'monthly_rate', 'num_companies_worked', 'overtime',
#        'percent_salary_hike', 'performance_rating',
#        'relationship_satisfaction', 'standard_hours', 'stock_option_level',
#        'total_working_years', 'training_times_last_year', 'work_life_balance',
#        'years_at_company', 'years_since_last_promotion',
#        'years_with_curr_manager', 'salary', 'remote_work'],
#       dtype='object')

# %% [markdown]
# Creamos nueva columna para sacar el promedio de los ídices de satisfacción de los empleados

# %%
df_testing["employee_satisfaction"]=df_testing[["environment_satisfaction", "job_satisfaction", "relationship_satisfaction"]].mean(axis=1).round(2)

# %%
df_testing.head()
# Out:
#    age attrition business_travel   daily_rate  distance_from_home  education  \
# 0   51        No         Unknown  2015.722222                   6          3
# 1   52        No         Unknown  2063.388889                   1          4
# 2   42        No   travel_rarely  1984.253968                   4          2
# 3   47        No   travel_rarely  1771.404762                   2          4
# 4   46        No         Unknown  1582.771346                   3          3
#
#     education_field  employee_number  environment_satisfaction gender  \
# 0           Unknown                1                         1      M
# 1     life sciences                2                         3      M
# 2  technical degree                3                         3      M
# 3           medical                4                         1      F
# 4  technical degree                5                         1      F
#
#    job_involvement  job_level             job_role  job_satisfaction  \
# 0                3          5   research director                  3
# 1                2          5             manager                  3
# 2                3          5             manager                  4
# 3                3          4   research director                  3
# 4                4          4     sales executive                  1
#
#   marital_status  monthly_income  monthly_rate  num_companies_worked overtime  \
# 0        Unknown        16280.83      42330.17                     7       no
# 1        Unknown        16665.83      43331.17                     0  Unknown
# 2        married        16026.67      41669.33                     1       no
# 3        married        14307.50      37199.50                     3  Unknown
# 4       divorced        12783.92      33238.20                     2       no
#
#    percent_salary_hike  performance_rating  relationship_satisfaction  \
# 0                   13                 3.0                          3
# 1                   14                 3.0                          1
# 2                   11                 3.0                          4
# 3                   19                 3.0                          2
# 4                   12                 3.0                          4
#
#   standard_hours  stock_option_level total_working_years  \
# 0      Full Time                   0             Unknown
# 1        Unknown                   1                34.0
# 2        Unknown                   0                22.0
# 3      Full Time                   2             Unknown
# 4        Unknown                   1             Unknown
#
#    training_times_last_year work_life_balance  years_at_company  \
# 0                         5               3.0                20
# 1                         5               3.0                33
# 2                         3           Unknown                22
# 3                         2           Unknown                20
# 4                         5               3.0                19
#
#    years_since_last_promotion  years_with_curr_manager     salary remote_work  \
# 0                          15                       15  195370.00           Y
# 1                          11                        9  199990.00           Y
# 2                          11                       15  192320.00           Y
# 3                           5                        6  171690.00           N
# 4                           2                        8  153407.04           N
#
#    employee_satisfaction groups
# 0                   2.33      B
# 1                   2.33      B
# 2                   3.67      A
# 3                   2.00      B
# 4                   2.00      B

# %% [markdown]
# **Creamos grupos de satisfacción en dos columnas A y B**
#
#
#
#     Grupo A (Control): Empleados con un nivel de satisfacción en el trabajo igual o superior a 3 en una escala de 1 a 4.
#
#     Grupo B (Variante): Empleados con un nivel de satisfacción en el trabajo inferior a 3 en la misma escala.

# %%
df_testing["groups"] = np.where(df_testing['employee_satisfaction'] >= 3, 'A', 'B')
df_testing.head(2)
# Out:
#    age attrition business_travel   daily_rate  distance_from_home  education  \
# 0   51        No         Unknown  2015.722222                   6          3
# 1   52        No         Unknown  2063.388889                   1          4
#
#   education_field  employee_number  environment_satisfaction gender  \
# 0         Unknown                1                         1      M
# 1   life sciences                2                         3      M
#
#    job_involvement  job_level             job_role  job_satisfaction  \
# 0                3          5   research director                  3
# 1                2          5             manager                  3
#
#   marital_status  monthly_income  monthly_rate  num_companies_worked overtime  \
# 0        Unknown        16280.83      42330.17                     7       no
# 1        Unknown        16665.83      43331.17                     0  Unknown
#
#    percent_salary_hike  performance_rating  relationship_satisfaction  \
# 0                   13                 3.0                          3
# 1                   14                 3.0                          1
#
#   standard_hours  stock_option_level total_working_years  \
# 0      Full Time                   0             Unknown
# 1        Unknown                   1                34.0
#
#    training_times_last_year work_life_balance  years_at_company  \
# 0                         5               3.0                20
# 1                         5               3.0                33
#
#    years_since_last_promotion  years_with_curr_manager    salary remote_work  \
# 0                          15                       15  195370.0           Y
# 1                          11                        9  199990.0           Y
#
#    employee_satisfaction groups
# 0                   2.33      B
# 1                   2.33      B

# %%
def exploratory_data(dataframe, columna_groups): 

    print(f"La columna {columna_groups} tiene las siguientes valores únicos:")
    display(pd.DataFrame(dataframe[columna_groups].value_counts()))    
    

    for categoria in dataframe[columna_groups].unique():
        
        dataframe_filtrado = dataframe[dataframe[columna_groups] == categoria]
    
        print("\n ..................... \n")
        print(f"Los principales estadísticos de las columnas categóricas para el grupo {categoria.upper()} son: ")
        display(dataframe_filtrado.describe(include = "O").T)
        
        print("\n ..................... \n")
        print(f"Los principales estadísticos de las columnas numéricas para el grupo {categoria.upper()} son: ")
        display(dataframe_filtrado.describe().T)

# %%
exploratory_data(df_testing, "groups")
# Out:
# La columna groups tiene las siguientes valores únicos:
#         count
# groups
# B         842
# A         772
#  .....................
#
# Los principales estadísticos de las columnas categóricas para el grupo B son:
#                     count unique                top freq
# attrition             842      2                 No  680
# business_travel       842      4            Unknown  387
# education_field       842      7            Unknown  384
# gender                842      2                  M  490
# job_role              842      9   sales executive   193
# marital_status        842      4            Unknown  359
# overtime              842      3                 no  371
# standard_hours        842      3          Part Time  462
# total_working_years   842     39            Unknown  268
# work_life_balance     842      5                3.0  480
# remote_work           842      2                  Y  511
# groups                842      1                  B  842
#  .....................
#
# Los principales estadísticos de las columnas numéricas para el grupo B son:
#                             count          mean           std           min  \
# age                         842.0     36.720903      8.987996     18.000000
# daily_rate                  842.0    667.451410    466.709472    108.539683
# distance_from_home          842.0      9.986936      9.352577      1.000000
# education                   842.0      2.967933      1.010135      1.000000
# employee_number             842.0    806.932304    466.440458      1.000000
# environment_satisfaction    842.0      2.243468      1.058957      1.000000
# job_involvement             842.0      2.747031      0.714316      1.000000
# job_level                   842.0      2.061758      1.089780      1.000000
# job_satisfaction            842.0      2.255344      1.070689      1.000000
# monthly_income              842.0   5390.952300   3769.577205    876.667000
# monthly_rate                842.0  14016.480380   9800.898378   2279.330000
# num_companies_worked        842.0      2.647268      2.499046      0.000000
# percent_salary_hike         842.0     15.299287      3.694418     11.000000
# performance_rating          842.0      3.137767      0.344860      3.000000
# relationship_satisfaction   842.0      2.287411      1.063080      1.000000
# stock_option_level          842.0      0.813539      0.872165      0.000000
# training_times_last_year    842.0      2.849169      1.297507      0.000000
# years_at_company            842.0      7.211401      6.105530      0.000000
# years_since_last_promotion  842.0      2.317102      3.313636      0.000000
# years_with_curr_manager     842.0      4.375297      3.672925      0.000000
# salary                      842.0  64691.441164  45234.919878  10520.000000
# employee_satisfaction       842.0      2.262542      0.410608      1.000000
#
#                                     25%           50%          75%  \
# age                            30.00000     36.000000     42.00000
# daily_rate                    290.03551    556.256661    991.81746
# distance_from_home              2.00000      7.000000     15.00000
# education                       2.00000      3.000000      4.00000
# employee_number               413.50000    788.000000   1211.00000
# environment_satisfaction        1.00000      2.000000      3.00000
# job_involvement                 2.00000      3.000000      3.00000
# job_level                       1.00000      2.000000      3.00000
# job_satisfaction                1.00000      2.000000      3.00000
# monthly_income               2342.59000   4492.840000   8010.83000
# monthly_rate                 6090.75000  11681.390000  20828.17000
# num_companies_worked            1.00000      1.500000      4.00000
# percent_salary_hike            12.00000     14.000000     18.00000
# performance_rating              3.00000      3.000000      3.00000
# relationship_satisfaction       1.00000      2.000000      3.00000
# stock_option_level              0.00000      1.000000      1.00000
# training_times_last_year        2.00000      3.000000      3.00000
# years_at_company                3.00000      5.000000     10.00000
# years_since_last_promotion      0.00000      1.000000      3.00000
# years_with_curr_manager         2.00000      3.000000      7.00000
# salary                      28111.13000  53914.110000  96129.99000
# employee_satisfaction           2.00000      2.330000      2.67000
#
#                                       max
# age                             60.000000
# daily_rate                    2063.388889
# distance_from_home              49.000000
# education                        5.000000
# employee_number               1611.000000
# environment_satisfaction         4.000000
# job_involvement                  4.000000
# job_level                        5.000000
# job_satisfaction                 4.000000
# monthly_income               16665.830000
# monthly_rate                 43331.170000
# num_companies_worked             9.000000
# percent_salary_hike             25.000000
# performance_rating               4.000000
# relationship_satisfaction        4.000000
# stock_option_level               3.000000
# training_times_last_year         6.000000
# years_at_company                36.000000
# years_since_last_promotion      15.000000
# years_with_curr_manager         17.000000
# salary                      199990.000000
# employee_satisfaction            2.670000
#  .....................
#
# Los principales estadísticos de las columnas categóricas para el grupo A son:
#                     count unique                top freq
# attrition             772      2                 No  675
# business_travel       772      4            Unknown  385
# education_field       772      7            Unknown  361
# gender                772      2                  M  481
# job_role              772      9   sales executive   176
# marital_status        772      4            Unknown  292
# overtime              772      3            Unknown  327
# standard_hours        772      3          Part Time  426
# total_working_years   772     40            Unknown  258
# work_life_balance     772      5                3.0  433
# remote_work           772      2                  Y  489
# groups                772      1                  A  772
#  .....................
#
# Los principales estadísticos de las columnas numéricas para el grupo A son:
#                             count          mean           std           min  \
# age                         772.0     37.138601      9.225955     18.000000
# daily_rate                  772.0    672.007548    478.724703    104.103175
# distance_from_home          772.0     12.401554     11.402978      1.000000
# education                   772.0      2.878238      1.034147      1.000000
# employee_number             772.0    808.119171    465.958790      3.000000
# environment_satisfaction    772.0      6.532383      9.565135      1.000000
# job_involvement             772.0      2.731865      0.708935      1.000000
# job_level                   772.0      2.075130      1.114486      1.000000
# job_satisfaction            772.0      3.265544      0.881106      1.000000
# monthly_income              772.0   5429.777184   3864.674394    840.833000
# monthly_rate                772.0  14112.159054  10053.218255   2186.170000
# num_companies_worked        772.0      2.702073      2.515188      0.000000
# percent_salary_hike         772.0     15.019430      3.594691     11.000000
# performance_rating          772.0      3.126943      0.333125      3.000000
# relationship_satisfaction   772.0      3.159326      0.897758      1.000000
# stock_option_level          772.0      0.766839      0.808540      0.000000
# training_times_last_year    772.0      2.766839      1.297524      0.000000
# years_at_company            772.0      7.046632      6.147382      0.000000
# years_since_last_promotion  772.0      2.168394      3.148736      0.000000
# years_with_curr_manager     772.0      4.051813      3.432871      0.000000
# salary                      772.0  65157.337591  46376.086509  10090.000000
# employee_satisfaction       772.0      4.318718      3.096996      3.000000
#
#                                     25%           50%          75%  \
# age                            30.00000     35.000000     43.00000
# daily_rate                    290.03551    556.256661    956.55754
# distance_from_home              3.00000      9.000000     19.00000
# education                       2.00000      3.000000      4.00000
# employee_number               397.25000    831.500000   1210.25000
# environment_satisfaction        3.00000      4.000000      4.00000
# job_involvement                 2.00000      3.000000      3.00000
# job_level                       1.00000      2.000000      3.00000
# job_satisfaction                3.00000      4.000000      4.00000
# monthly_income               2342.59000   4492.840000   7726.04000
# monthly_rate                 6090.75000  11681.390000  20087.71000
# num_companies_worked            1.00000      2.000000      4.00000
# percent_salary_hike            12.00000     14.000000     17.00000
# performance_rating              3.00000      3.000000      3.00000
# relationship_satisfaction       3.00000      3.000000      4.00000
# stock_option_level              0.00000      1.000000      1.00000
# training_times_last_year        2.00000      3.000000      3.00000
# years_at_company                3.00000      5.000000      9.00000
# years_since_last_promotion      0.00000      1.000000      2.00000
# years_with_curr_manager         2.00000      3.000000      7.00000
# salary                      28111.13000  53914.110000  92712.50000
# employee_satisfaction           3.00000      3.330000      3.67000
#
#                                       max
# age                             60.000000
# daily_rate                    2047.706349
# distance_from_home              49.000000
# education                        5.000000
# employee_number               1614.000000
# environment_satisfaction        49.000000
# job_involvement                  4.000000
# job_level                        5.000000
# job_satisfaction                 4.000000
# monthly_income               16539.170000
# monthly_rate                 43001.830000
# num_companies_worked             9.000000
# percent_salary_hike             25.000000
# performance_rating               4.000000
# relationship_satisfaction        4.000000
# stock_option_level               3.000000
# training_times_last_year         6.000000
# years_at_company                40.000000
# years_since_last_promotion      15.000000
# years_with_curr_manager         17.000000
# salary                      198470.000000
# employee_satisfaction           19.000000

# %% [markdown]
# Después del análisis exploratorio, usaremos la columna "Attrition" para obtener la métrica principal. Siendo:
#
#     -  "NO" indica que el empleado no ha dejado la empresa (sin rotación).
#     - "YES" indica que el empleado ha dejado la empresa (con rotación).

# %%
df_attrition = df_testing[["groups", "attrition", "job_satisfaction", "relationship_satisfaction", "environment_satisfaction"]]
df_attrition.head()
# Out:
#   groups attrition  job_satisfaction  relationship_satisfaction  \
# 0      B        No                 3                          3
# 1      B        No                 3                          1
# 2      A        No                 4                          4
# 3      B        No                 3                          2
# 4      B        No                 1                          4
#
#    environment_satisfaction
# 0                         1
# 1                         3
# 2                         3
# 3                         1
# 4                         1

# %%
df_attrition.describe().T
# Out:
#                             count      mean       std  min  25%  50%  75%  \
# job_satisfaction           1614.0  2.738538  1.106163  1.0  2.0  3.0  4.0
# relationship_satisfaction  1614.0  2.704461  1.079031  1.0  2.0  3.0  4.0
# environment_satisfaction   1614.0  4.294919  6.993559  1.0  2.0  3.0  4.0
#
#                             max
# job_satisfaction            4.0
# relationship_satisfaction   4.0
# environment_satisfaction   49.0

# %%
# Contar el número de empleados por grupo
group_counts = df_attrition['groups'].value_counts()

# Reordenar los grupos de modo que 'A' quede primero y 'B' después
group_counts = group_counts[['A', 'B']]

# Crear el gráfico de barras
plt.figure(figsize=(12, 8))
sns.barplot(x=group_counts.index, y=group_counts.values, palette = "Paired")

# Añadir título
plt.title("Relation between Groups and Number of employees", fontsize=14)

# Etiquetas
plt.xlabel('Groups', fontsize=12)
plt.ylabel('Number of employees', fontsize=12)

# Añadir leyenda con la información de satisfacción
plt.legend(labels=['Satisfied (A)', 'Not Satisfied (B)',], loc='upper left')

# Mostrar el gráfico
plt.show()

# %% [markdown]
# La gráfica muestra:
# La empresa tiene más empleados no satisfechos (Grupo B) que satisfechos (Grupo A).
# Esto puede ser un indicador de problemas organizacionales relacionados con el entorno laboral, las condiciones de trabajo, o la satisfacción general de los empleados.

# %% [markdown]
# Agrupamos y posteriormente calculamos la tasa de rotación

# %%
df_grupoA = df_attrition[df_attrition["groups"]== "A"] 

df_grupoB = df_attrition[df_attrition["groups"]== "B"]

# %%
df_grupoA.groupby("attrition")["groups"].count().reset_index()
# Out:
#   attrition  groups
# 0        No     675
# 1       Yes      97

# %%
df_grupoB.groupby("attrition")["groups"].count().reset_index()
# Out:
#   attrition  groups
# 0        No     680
# 1       Yes     162

# %%
tasa_rotacionA=np.round(df_grupoA[df_grupoA["attrition"]== "Yes"].shape[0]/df_grupoA.shape[0],2)

print(tasa_rotacionA)
# Out:
# 0.13

# %%
tasa_rotacionB=np.round(df_grupoB[df_grupoB["attrition"]== "Yes"].shape[0]/df_grupoB.shape[0],2)

print(tasa_rotacionB)
# Out:
# 0.19

# %%
dicc_grupos_rotacion={"groups":["A", "B"], "turnover_rate":[tasa_rotacionA,tasa_rotacionB]}

# %%
df_grupos_rotacion=pd.DataFrame(dicc_grupos_rotacion)

df_grupos_rotacion
# Out:
#   groups  turnover_rate
# 0      A           0.13
# 1      B           0.19

# %%
labels = df_grupos_rotacion['groups']
sizes = df_grupos_rotacion['turnover_rate']

# Crear el gráfico de pastel
plt.figure(figsize=(7, 7))  # Tamaño de la figura
plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=90, colors=['skyblue', 'lightgreen'])

# Agregar un título
plt.title('Relation Between Turnover Rate and Groups Test')

plt.legend(labels=labels, title="Groups", loc="best", fontsize=12)

# Mostrar el gráfico
plt.show()

# %% [markdown]
# Observamos en este gráfico que el Grupo B contribuye más a la tasa de rotación (59.4%). Esto indica que hay algo en las condiciones del Grupo B que podría estar impulsando una mayor rotación, como:
# - Menor satisfacción laboral.
# - Diferencias en las condiciones laborales.
# - Oportunidades externas más atractivas.

# %%
# Comparacion "Attrition" con "Job_satisfaction"

plt.figure(figsize=(8, 5)) 
sns.barplot(x = "attrition", 
            y = "job_satisfaction", 
            data = df_attrition, 
            palette = "Set3");

# Ajustar manualmente el rango del eje Y
plt.ylim(1, 4)  # Establecer el rango de valores del eje Y entre 1 y 4

plt.xlabel("Attrition", fontsize = 11)
plt.ylabel("Job Satisfaction",  fontsize = 11); 
plt.title("Relation between Attrition and Job satisfaction rate " , fontsize = 14);

# %% [markdown]
# Podemos interpretar la gráfica de la siguiente manera: Si los empleados están satisfechos, tienen más probabilidades de quedarse; si están insatisfechos, es más probable que se vayan.

# %% [markdown]
# Esas líneas negras encima de las barras muestran un rango llamado error estándar. Este rango nos ayuda a entender cuánto puede variar el promedio (en este caso, la satisfacción laboral) si tomamos diferentes muestras de los empleados.
# En este caso, las líneas negras son cortas, lo que significa que los datos no varían mucho y son bastante precisos. Si las líneas negras no se tocan, podemos asumir que la diferencia entre "Yes" y "No" en satisfacción laboral es real y no por azar.

# %%
df_attrition.groupby("attrition")["job_satisfaction"].mean().reset_index()
# Out:
#   attrition  job_satisfaction
# 0        No          2.786716
# 1       Yes          2.486486

# %%
# Comparacion "Attrition" con "Environment_satisfaction"

plt.figure(figsize=(8, 5))
sns.barplot(x="attrition", 
            y="environment_satisfaction", 
            data=df_attrition, 
            hue="attrition", 
            palette=["#E0B0FF", "#B2F1B3"],
            ci=None)  

plt.xlabel("Attrition", fontsize = 11)
plt.ylabel("Environment Satisfaction",  fontsize = 11); 
plt.title("Relation between Attrition and Environment Satisfaction Rate " , fontsize = 14);

# %% [markdown]
#  Observamos que los empleados que se fueron tienen una satisfacción baja con su entorno de trabajo y los que se quedan tienen una satisfacción más alta, podemos concluir que un ambiente de trabajo agradable y cómodo puede ser un factor clave para que los empleados decidan quedarse en la empresa.

# %% [markdown]
# A continuación, definiremos si es un problema de proporciones o de media

# %%
df_attrition.groupby("attrition")["environment_satisfaction"].mean().reset_index()
# Out:
#   attrition  environment_satisfaction
# 0        No                  4.466421
# 1       Yes                  3.397683

# %% [markdown]
# Todas estas pruebas demuestran que nos encontramos con un problema de proporciones, por lo que, como attrition y groups son ambas variables categóricas, utilizamos la prueba de Chi-cuadrado para analizar la correlación entre ellas.

# %% [markdown]
# ### Pruebas estadísticas ###

# %% [markdown]
# Hipótesis:
#
# - Hipótesis nula (H0): No existe una relación entre el nivel de satisfacción en el trabajo y la rotación de empleados en la empresa.
#
# - Hipótesis alternativa (H1): Existe una relación entre el nivel de satisfacción en el trabajo y la rotación de empleados en la empresa.

# %%
#Creamos una tabla de contingencia

tabla_contingencia = pd.crosstab(df_testing ["groups"], df_testing["attrition"])

tabla_contingencia
# Out:
# attrition   No  Yes
# groups
# A          675   97
# B          680  162

# %%
_, p_value, _, _ = chi2_contingency(tabla_contingencia)
print(p_value)
# Out:
# 0.0003412084634863277

# %% [markdown]
# Si p_value < 0.05: Existe una diferencia significativa
#
# Si p_value > 0.05: No existe una diferencia significativa

# %%
p_value<0.05
# Out:
# True

# %% [markdown]
# Con este resultado podemos decir que NO rechazamos la hipótesis alternativa (H1):
#
# Existe una relación entre el nivel de satisfacción en el trabajo y la rotación de empleados en la empresa.

# %% [markdown]
# Como valor agregado, vamos a realizar una comparativa de los empleados que se van y los que se quedan en función del salario.

# %%
pd.crosstab(df_testing ["groups"], df_testing["salary"])
# Out:
# salary  10090.00   10520.00   10910.00   11290.00   12000.00   12740.00   \
# groups
# A               1          0          0          1          0          1
# B               0          1          1          0          1          0
#
# salary  13930.00   14199.96   15630.00   15690.00   16110.00   17020.00   \
# groups
# A               0          1          0          1          1          1
# B               1          0          1          0          0          0
#
# salary  18780.00   19510.00   20010.00   20080.00   20130.00   20140.00   \
# groups
# A               0          1          0          1          0          1
# B               1          0          1          0          1          0
#
# salary  20220.00   20240.00   20290.00   20330.00   20420.00   20420.04   \
# groups
# A               0          1          0          1          0          0
# B               1          0          1          1          1          1
#
# salary  20450.00   20620.00   20640.00   20660.00   20700.00   20739.96   \
# groups
# A               1          0          0          0          2          1
# B               0          1          1          1          0          0
#
# salary  20800.00   20830.00   20860.00   20900.00   20960.00   21050.00   \
# groups
# A               0          1          1          1          1          0
# B               1          0          0          0          0          1
#
# salary  21070.00   21189.96   21210.00   21270.00   21410.00   21440.00   \
# groups
# A               0          0          0          1          0          1
# B               1          2          1          0          1          0
#
# salary  21440.04   21480.00   21660.00   21740.00   21760.00   21770.00   \
# groups
# A               1          1          0          0          1          0
# B               0          0          1          2          0          1
#
# salary  21870.00   22070.00   22100.00   22160.00   22179.96   22180.00   \
# groups
# A               0          0          0          1          0          0
# B               1          1          1          1          1          1
#
# salary  22260.00   22440.00   22580.00   22580.04   22590.00   22690.00   \
# groups
# A               0          0          2          1          0          0
# B               1          1          0          0          1          1
#
# salary  22740.00   22850.00   22900.00   22970.04   23020.00   23050.00   \
# groups
# A               1          1          1          1          0          1
# B               0          0          0          0          1          0
#
# salary  23080.00   23140.00   23180.04   23220.00   23280.00   23290.00   \
# groups
# A               0          1          0          0          1          0
# B               2          0          1          1          0          2
#
# salary  23400.00   23480.00   23620.00   23660.00   23700.00   23720.00   \
# groups
# A               1          0          0          0          0          0
# B               0          1          1          2          1          1
#
# salary  23760.00   23770.00   23790.00   23799.96   23800.00   23890.00   \
# groups
# A               2          0          1          0          1          1
# B               0          2          0          1          0          0
#
# salary  23940.00   24000.00   24040.00   24130.00   24300.00   24370.00   \
# groups
# A               1          1          1          0          0          1
# B               0          0          1          1          1          0
#
# salary  24390.00   24500.00   24550.00   24610.00   24680.00   24759.96   \
# groups
# A               1          1          0          0          0          0
# B               0          0          2          1          1          1
#
# salary  24790.00   24960.00   25010.00   25140.00   25170.00   25190.00   \
# groups
# A               0          1          0          0          0          1
# B               1          0          1          1          1          0
#
# salary  25320.00   25389.96   25390.00   25430.00   25430.04   25460.00   \
# groups
# A               0          1          1          1          1          0
# B               1          0          0          0          0          1
#
# salary  25520.04   25530.00   25590.00   25610.00   25640.00   25659.96   \
# groups
# A               0          1          1          0          0          1
# B               1          0          0          1          1          0
#
# salary  25700.00   25710.00   25719.96   25800.00   25869.96   25870.00   \
# groups
# A               1          1          0          1          0          1
# B               0          0          1          0          1          0
#
# salary  25930.00   25960.00   26000.00   26100.00   26220.00   26420.00   \
# groups
# A               0          0          0          2          1          1
# B               1          1          1          0          0          0
#
# salary  26540.00   26550.00   26570.00   26570.04   26589.96   26600.00   \
# groups
# A               2          1          2          0          1          1
# B               0          0          0          1          0          0
#
# salary  26619.96   26780.00   26830.00   26840.00   26900.04   26910.00   \
# groups
# A               0          1          0          0          1          1
# B               1          0          1          1          0          0
#
# salary  26940.00   26960.00   26960.04   27000.00   27050.00   27180.00   \
# groups
# A               0          1          1          2          0          0
# B               1          0          0          0          1          1
#
# salary  27230.00   27250.00   27410.00   27410.04   27430.00   27600.00   \
# groups
# A               1          0          0          0          0          0
# B               0          1          1          1          1          1
#
# salary  27660.00   27680.00   27740.00   27820.00   27890.00   27910.00   \
# groups
# A               0          1          0          1          1          0
# B               1          0          1          1          0          2
#
# salary  27930.00   27990.00   28040.00   28090.00   28100.00   28110.00   \
# groups
# A               0          0          1          1          0          1
# B               1          1          0          0          1          0
#
# salary  28111.08   28111.13   28209.96   28210.00   28270.00   28350.00   \
# groups
# A              31        111          0          0          0          0
# B              20        133          1          1          1          1
#
# salary  28380.00   28510.00   28530.00   28560.00   28580.04   28620.00   \
# groups
# A               0          1          1          0          0          0
# B               1          0          0          1          1          1
#
# salary  28630.00   28970.00   28990.00   29040.00   29090.00   29110.00   \
# groups
# A               0          0          0          2          1          1
# B               1          1          1          0          1          0
#
# salary  29259.96   29290.00   29330.00   29360.00   29560.00   29600.00   \
# groups
# A               1          0          0          1          0          0
# B               0          1          1          0          1          1
#
# salary  29720.00   29730.00   29740.00   29940.80   29960.00   30220.00   \
# groups
# A               1          1          1          1          1          0
# B               0          0          0          0          0          1
#
# salary  30340.00   30380.04   30550.00   30580.00   30690.00   30720.00   \
# groups
# A               0          0          1          1          1          0
# B               2          1          0          0          0          1
#
# salary  31020.00   31170.00   31310.04   31430.00   31490.00   31610.00   \
# groups
# A               0          1          0          0          1          1
# B               1          0          1          1          0          0
#
# salary  31620.00   31800.00   31960.00   32100.00   32109.96   32120.00   \
# groups
# A               1          1          0          1          1          1
# B               0          0          1          0          0          0
#
# salary  32290.00   32300.00   33060.00   33120.00   33480.00   33750.00   \
# groups
# A               0          0          1          1          0          1
# B               1          1          0          0          1          0
#
# salary  33760.00   33770.00   33880.00   34070.00   34080.00   34190.00   \
# groups
# A               0          0          0          1          0          0
# B               1          1          1          0          1          1
#
# salary  34200.00   34240.00   34329.96   34410.00   34450.00   34470.00   \
# groups
# A               1          0          0          1          1          1
# B               1          1          1          0          0          0
#
# salary  34479.96   34520.00   34770.00   34910.00   35390.00   35390.04   \
# groups
# A               0          1          1          0          0          0
# B               1          1          0          1          1          1
#
# salary  35640.00   35780.00   35790.00   35799.96   35910.00   35970.00   \
# groups
# A               0          0          0          0          0          1
# B               1          1          1          1          1          0
#
# salary  36170.00   36220.00   36290.00   36600.00   36810.00   36920.00   \
# groups
# A               1          1          0          1          1          0
# B               0          0          1          0          0          1
#
# salary  37020.00   37080.00   37550.00   37600.00   37800.00   38150.00   \
# groups
# A               1          0          0          0          1          1
# B               0          1          1          2          0          0
#
# salary  38670.00   38860.00   38940.00   39020.00   39040.00   39070.00   \
# groups
# A               1          1          1          1          1          0
# B               0          0          0          0          1          1
#
# salary  39170.00   39200.00   39290.00   39360.00   39440.00   39780.00   \
# groups
# A               0          1          1          0          1          0
# B               1          0          0          1          0          1
#
# salary  39830.00   39890.00   39999.96   40010.00   40140.00   40510.00   \
# groups
# A               2          0          0          1          1          0
# B               0          1          1          0          0          2
#
# salary  40660.00   40689.96   40710.00   40810.00   40869.96   41070.00   \
# groups
# A               1          1          0          0          0          0
# B               0          0          1          1          1          1
#
# salary  41150.00   41270.00   41619.96   41630.04   41870.00   41940.00   \
# groups
# A               0          1          1          1          0          0
# B               1          0          0          0          1          1
#
# salary  41970.00   42000.00   42130.00   42210.00   42270.00   42300.00   \
# groups
# A               1          0          0          0          0          1
# B               1          1          1          1          1          0
#
# salary  42330.00   42399.96   42440.00   42440.04   42490.00   42560.00   \
# groups
# A               0          0          1          1          0          0
# B               1          1          0          0          1          1
#
# salary  42580.00   42620.00   42840.00   42850.00   42940.00   43059.96   \
# groups
# A               1          1          0          0          1          0
# B               0          0          1          1          1          1
#
# salary  43060.00   43170.00   43190.00   43230.00   43350.00   43420.00   \
# groups
# A               0          1          0          0          0          1
# B               1          0          1          1          2          0
#
# salary  43730.00   43740.00   43770.00   43810.00   43820.00   43850.04   \
# groups
# A               0          1          1          0          1          0
# B               1          0          0          1          0          1
#
# salary  44000.00   44030.00   44040.00   44220.00   44240.00   44250.00   \
# groups
# A               0          1          0          1          1          0
# B               1          0          1          0          0          1
#
# salary  44400.00   44440.00   44470.00   44480.00   45020.00   45050.00   \
# groups
# A               0          0          1          0          1          1
# B               1          1          1          1          0          0
#
# salary  45340.00   45370.00   45380.00   45560.00   45580.00   45680.00   \
# groups
# A               0          0          0          0          0          1
# B               1          1          1          1          1          0
#
# salary  45770.00   46150.00   46270.00   46390.00   46480.00   46490.00   \
# groups
# A               0          0          0          1          1          0
# B               1          1          1          0          0          1
#
# salary  46680.00   46820.04   47210.00   47229.96   47280.00   47350.00   \
# groups
# A               1          2          1          0          1          1
# B               0          0          0          1          0          0
#
# salary  47390.04   47660.00   47680.00   47740.00   47770.00   47870.00   \
# groups
# A               1          0          0          1          0          1
# B               0          1          1          0          1          0
#
# salary  48050.00   48410.00   48500.00   48510.00   48549.96   48590.00   \
# groups
# A               0          0          1          1          0          0
# B               2          1          0          0          1          1
#
# salary  48690.00   48760.00   48770.00   48830.00   48980.00   49300.00   \
# groups
# A               1          1          0          0          0          0
# B               0          0          1          1          1          1
#
# salary  49410.00   49599.96   49600.00   49630.00   49680.00   49690.00   \
# groups
# A               1          1          1          0          1          0
# B               1          0          0          1          0          1
#
# salary  50060.04   50100.00   50210.00   50550.00   50670.00   50700.00   \
# groups
# A               0          0          1          0          1          0
# B               1          1          0          2          0          1
#
# salary  50710.00   50940.00   50980.00   51210.00   51260.00   51470.00   \
# groups
# A               1          0          0          0          1          1
# B               0          1          1          1          0          0
#
# salary  51510.00   51540.00   51550.00   51710.00   52040.00   52060.00   \
# groups
# A               0          1          0          1          1          1
# B               1          1          1          0          0          0
#
# salary  52200.00   52280.00   52380.00   52569.96   52570.00   52580.00   \
# groups
# A               1          0          0          0          0          1
# B               0          2          1          1          1          0
#
# salary  52650.00   52940.00   53040.00   53090.00   53210.04   53240.00   \
# groups
# A               0          1          2          1          0          0
# B               1          0          2          0          1          1
#
# salary  53260.00   53370.00   53630.00   53680.00   53730.00   53914.08   \
# groups
# A               0          2          1          1          0         30
# B               1          0          0          0          2         26
#
# salary  53914.11   53960.00   53960.04   53990.00   54050.00   54060.00   \
# groups
# A             138          1          1          0          0          1
# B             123          0          0          1          2          0
#
# salary  54100.00   54410.04   54540.00   54670.00   54680.00   54720.00   \
# groups
# A               0          1          0          1          0          1
# B               1          0          1          0          2          0
#
# salary  54730.00   54849.96   54860.04   54870.00   54880.00   55050.00   \
# groups
# A               0          0          0          0          0          1
# B               1          1          1          1          1          0
#
# salary  55070.00   55610.00   55620.00   55770.00   56050.00   56469.96   \
# groups
# A               0          0          1          0          0          0
# B               1          1          0          1          2          1
#
# salary  56610.00   56660.00   56740.00   56750.00   56750.04   56769.96   \
# groups
# A               0          1          0          0          0          0
# B               1          0          1          1          1          1
#
# salary  57310.00   57470.00   57690.00   58130.00   58130.04   58280.00   \
# groups
# A               2          1          1          1          1          1
# B               0          0          1          0          0          0
#
# salary  58280.04   58779.96   59020.00   59140.00   59330.00   59400.00   \
# groups
# A               1          0          1          1          1          1
# B               0          1          0          0          0          0
#
# salary  59740.00   59800.00   59930.00   60620.00   60740.00   61420.00   \
# groups
# A               0          0          0          1          0          0
# B               2          2          1          0          1          1
#
# salary  61460.00   61620.00   61720.00   61800.00   62010.00   62090.00   \
# groups
# A               1          1          0          1          1          1
# B               0          1          1          0          0          0
#
# salary  62610.00   62720.00   62740.00   62880.00   62940.00   63220.00   \
# groups
# A               1          0          1          0          1          1
# B               0          1          0          1          0          0
#
# salary  63470.00   63470.04   63489.96   63800.00   63850.00   63879.96   \
# groups
# A               2          1          1          1          1          0
# B               1          0          0          0          0          1
#
# salary  63920.00   63970.00   64100.00   64390.00   64650.00   64720.00   \
# groups
# A               0          0          0          1          1          1
# B               1          1          2          0          0          0
#
# salary  64990.00   65000.04   65019.96   65130.00   65380.00   65400.00   \
# groups
# A               0          0          1          1          0          0
# B               1          1          0          0          2          1
#
# salary  65490.00   65530.00   65860.00   66320.00   66440.00   66460.00   \
# groups
# A               0          1          0          0          0          0
# B               1          0          1          2          1          1
#
# salary  66510.00   66530.04   66669.96   66730.00   66740.04   66870.00   \
# groups
# A               0          1          1          0          0          1
# B               1          0          0          1          1          0
#
# salary  67120.00   67250.00   67350.00   67550.00   67550.04   67810.00   \
# groups
# A               1          0          0          1          1          0
# B               0          2          1          0          0          1
#
# salary  68040.00   68150.00   68250.00   68420.00   69310.00   70830.00   \
# groups
# A               1          0          1          1          1          1
# B               0          1          0          0          0          0
#
# salary  70940.00   73140.00   73510.00   74030.00   74460.00   75250.00   \
# groups
# A               0          0          1          0          0          0
# B               1          2          0          1          1          1
#
# salary  75870.00   76390.00   76540.00   77559.96   78610.00   79880.00   \
# groups
# A               0          1          0          1          1          0
# B               2          0          1          1          0          1
#
# salary  80200.00   80950.00   81030.00   81200.00   82240.00   82370.00   \
# groups
# A               0          1          1          1          0          0
# B               1          0          0          0          2          1
#
# salary  83210.00   83760.00   83920.00   84120.00   85000.00   85780.00   \
# groups
# A               1          0          0          0          1          1
# B               0          1          2          1          0          0
#
# salary  87400.00   87930.00   88230.00   88470.00   88530.00   89380.00   \
# groups
# A               0          0          0          0          1          0
# B               1          2          1          1          0          1
#
# salary  89430.00   92040.00   92410.00   92780.00   93620.00   93800.00   \
# groups
# A               0          1          1          0          1          1
# B               1          0          0          1          0          0
#
# salary  94340.00   94390.00   95260.00   96020.00   96129.96   96130.00   \
# groups
# A               2          1          1          1          0          0
# B               0          0          0          0          1          1
#
# salary  96190.00   96670.00   97140.00   97240.00   97560.00   98240.00   \
# groups
# A               1          1          0          0          1          1
# B               0          1          1          1          0          0
#
# salary  98520.00   98880.00   99240.00   99360.00   99570.00   99850.00   \
# groups
# A               0          0          1          0          1          1
# B               1          1          0          1          0          0
#
# salary  99910.00   100071.84  100080.00  100480.00  101240.00  102480.00  \
# groups
# A               0         61          1          0          1          1
# B               1         78          0          1          0          0
#
# salary  102520.00  102660.00  103059.96  103250.00  104000.00  104220.00  \
# groups
# A               0          0          0          0          1          1
# B               1          1          1          2          0          0
#
# salary  104470.00  104480.04  104660.00  104750.00  104820.00  104960.00  \
# groups
# A               1          0          0          0          0          1
# B               0          1          1          1          1          0
#
# salary  105270.00  105520.00  105960.00  106500.00  107480.00  107610.00  \
# groups
# A               0          1          0          1          1          0
# B               1          0          1          0          0          1
#
# salary  107930.00  108450.00  108510.00  108540.00  108550.00  108830.00  \
# groups
# A               0          2          0          0          0          1
# B               1          0          1          1          1          0
#
# salary  109340.00  109380.00  109650.00  111030.00  111590.00  112440.00  \
# groups
# A               1          1          0          2          2          1
# B               0          0          2          0          0          0
#
# salary  112450.00  115100.00  117130.00  118779.96  119160.00  119350.00  \
# groups
# A               0          2          0          0          0          0
# B               1          0          2          1          1          1
#
# salary  120310.00  124900.00  127420.00  128080.00  129360.00  131160.00  \
# groups
# A               1          0          1          1          1          0
# B               0          1          0          0          0          1
#
# salary  131200.00  131910.00  131940.00  132060.00  132120.00  133200.00  \
# groups
# A               0          0          0          0          0          1
# B               1          1          1          1          2          0
#
# salary  133410.00  134020.00  134990.00  135030.00  135250.00  135490.00  \
# groups
# A               0          0          0          1          1          0
# B               1          1          1          0          0          1
#
# salary  135700.00  135770.00  135910.00  136640.00  137260.00  137570.00  \
# groups
# A               0          1          1          0          0          1
# B               1          0          0          1          1          0
#
# salary  137700.00  138720.00  139640.04  139730.00  144110.04  148140.00  \
# groups
# A               1          1          1          1          1          1
# B               0          0          0          0          0          0
#
# salary  152020.00  153407.04  153407.07  154270.00  159720.00  159920.00  \
# groups
# A               1          3         21          0          0          0
# B               0          7         24          1          1          1
#
# salary  160149.96  160150.00  160640.00  161840.00  164220.00  165950.00  \
# groups
# A               0          0          1          0          0          0
# B               1          1          0          1          1          1
#
# salary  165980.00  166270.00  167040.00  167520.00  168560.00  168850.00  \
# groups
# A               0          1          1          1          0          0
# B               1          0          0          0          1          1
#
# salary  169590.00  170460.00  170680.00  170990.00  171230.00  171590.00  \
# groups
# A               1          1          0          1          1          0
# B               0          1          1          0          0          1
#
# salary  171690.00  171740.04  173280.00  173990.00  175670.00  175840.00  \
# groups
# A               0          1          1          1          0          1
# B               1          0          0          0          1          0
#
# salary  176390.00  177790.00  178610.00  179240.00  180410.00  180610.00  \
# groups
# A               1          1          1          0          1          0
# B               0          0          1          1          0          1
#
# salary  181720.00  182130.00  182650.00  183030.00  186650.00  187400.04  \
# groups
# A               0          0          1          1          0          1
# B               1          1          0          0          1          0
#
# salary  187890.00  188440.00  189470.00  190330.00  190450.00  190810.00  \
# groups
# A               1          1          0          1          0          0
# B               0          0          1          0          2          1
#
# salary  191324.62  191324.64  191870.00  191890.00  191900.00  191970.00  \
# groups
# A              15          3          1          2          0          0
# B              12          7          0          0          1          1
#
# salary  192020.00  192320.00  192370.00  192460.00  192720.00  194060.00  \
# groups
# A               1          1          1          1          0          0
# B               0          0          0          0          1          1
#
# salary  194060.04  194310.00  194360.00  195129.96  195170.00  195370.00  \
# groups
# A               0          1          0          1          1          0
# B               1          0          1          0          0          1
#
# salary  195450.00  195860.00  197400.00  198450.00  198470.00  199730.00  \
# groups
# A               1          1          1          1          1          0
# B               0          0          0          0          0          1
#
# salary  199990.00
# groups
# A               0
# B               1

# %%
plt.figure(figsize=(8, 5))
sns.barplot(x="groups", 
            y="salary", 
            data=df_testing, 
            hue="groups", 
            palette=["#B3D9FF", "#F5F7A0"],
            ci=None)  

plt.xlabel("Groups", fontsize = 11)
plt.ylabel("Salary ($)",  fontsize = 11); 
plt.title("Relation between Salary and Satisfaction Groups" , fontsize = 14);

# %% [markdown]
# En esta gráfica podemos observar que el salario no influye en que los empleados dejen la empresa ya que ambos grupos tienen salarios muy similares.

# %%
# lo primero que hacemos es crear una función para testar la normalidad de los datos
def normalidad(dataframe, columna):
    """
    Evalúa la normalidad de una columna de datos de un DataFrame utilizando la prueba de Shapiro-Wilk.
    Parámetros:
        dataframe (DataFrame): El DataFrame que contiene los datos.
        columna (str): El nombre de la columna en el DataFrame que se va a evaluar para la normalidad.
    Returns:
        None: Imprime un mensaje indicando si los datos siguen o no una distribución normal.
    """
    statistic, p_value = stats.shapiro(dataframe[columna])
    if p_value > 0.05:
        print(f"Para la columna {columna} los datos siguen una distribución normal.")
    else:
        print(f"Para la columna {columna} los datos no siguen una distribución normal.")

# %%
normalidad(df_testing, "salary")
# Out:
# Para la columna salary los datos no siguen una distribución normal.

# %%
# como los datos no son normales realizamos una prueba no paramétrica: Mann_whitney

grupo_control = df_testing[df_testing["groups"]== "A"]["salary"]
grupo_test = df_testing[df_testing["groups"]== "B"]["salary"]

# %%
mannwhitneyu(grupo_control, grupo_test)
# Out:
# MannwhitneyuResult(statistic=325040.0, pvalue=0.9976441453604522)

# %%
_, p_value = mannwhitneyu(grupo_control, grupo_test)
print(p_value)
# Out:
# 0.9976441453604522

# %%
p_value>0.05
# Out:
# True

# %% [markdown]
# Si p_value < 0.05: Existe una diferencia significativa
#
# Si p_value > 0.05: No existe una diferencia significativa

# %% [markdown]
# Podemos reafirmar lo analizado en la gráfica anterior, no existe una diferencia significativa entre los salarios de ambos grupos, por lo que el salario no influye en la satisfación de los empleados.
